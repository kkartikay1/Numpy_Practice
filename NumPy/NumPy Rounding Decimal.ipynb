# %%
import numpy as np

# %%
arr=np.trunc([-3.1666,3.6667])
print(arr)
# Out:
# [-3.  3.]

# %%
arr=np.fix([-3.1666,3.6667])
print(arr)
# Out:
# [-3.  3.]

# %%
arr=np.around(3.1666,2)
print(arr)
# Out:
# 3.17

# %%
arr=np.around(3.16467,3)
print(arr)
# Out:
# 3.165

# %%
arr=np.around(3.16467,1)
print(arr)
# Out:
# 3.2

# %%
arr=np.around([-3.1666,3.6667],2)
print(arr)
# Out:
# [-3.17  3.67]

# %%
arr=np.floor([-3.1666,3.6667])
print(arr)
# Out:
# [-4.  3.]

# %%
arr=np.ceil([-3.1666,3.6667])
print(arr)
# Out:
# [-3.  4.]
