# %%
import numpy as np

# %%
a=np.array([10,20,30,40])
print(a,type(a))
# Out:
# [10 20 30 40] <class 'numpy.ndarray'>

# %%
b=a.copy()
print("Origancal Array ={} and {}".format(a,type(a)) )
print("Copied Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[10 20 30 40] and <class 'numpy.ndarray'>
# Copied Array =[10 20 30 40] and <class 'numpy.ndarray'>

# %%
print(a[0])
print(a[0])
# Out:
# 10
# 10

# %%
a[0]=100 #Modified Original array
print("Origancal Array ={} and {}".format(a,type(a)) )
print("Copied Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[100  20  30  40] and <class 'numpy.ndarray'>
# Copied Array =[10 20 30 40] and <class 'numpy.ndarray'>

# %%
b[0]=200 #Modified Copy array
print("Origancal Array ={} and {}".format(a,type(a)) )
print("Copied Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[100  20  30  40] and <class 'numpy.ndarray'>
# Copied Array =[200  20  30  40] and <class 'numpy.ndarray'>

# %%
#view()

# %%
a=np.array([10,20,30,40])
print(a,type(a))
# Out:
# [10 20 30 40] <class 'numpy.ndarray'>

# %%
b=a.view()
print("Origancal Array ={} and {}".format(a,type(a)) )
print("View Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[10 20 30 40] and <class 'numpy.ndarray'>
# View Array =[10 20 30 40] and <class 'numpy.ndarray'>

# %%
print(a[0])
print(a[0])
# Out:
# 10
# 10

# %%
a[0]=125 #Modified Original array
print("Origancal Array ={} and {}".format(a,type(a)) )
print("Copied Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[125  20  30  40] and <class 'numpy.ndarray'>
# Copied Array =[125  20  30  40] and <class 'numpy.ndarray'>

# %%
b[-1]=400 #Modified Original array
print("Origancal Array ={} and {}".format(a,type(a)) )
print("Copied Array ={} and {}".format(b,type(b)) )
# Out:
# Origancal Array =[125  20  30 400] and <class 'numpy.ndarray'>
# Copied Array =[125  20  30 400] and <class 'numpy.ndarray'>

# %%
print("a={} addr of a ={}".format(a,id(a)))
print("b={} addr of a ={}".format(b,id(b)))
# Out:
# a=[125  20  30 400] addr of a =2587599358832
# b=[125  20  30 400] addr of a =2587599358352

# %%
a=np.array([10,20,30,40])
b=a.copy()
print(a,a.base)
print(b,b.base)
# Out:
# [10 20 30 40] <class 'numpy.ndarray'>
# [10 20 30 40] None
# [10 20 30 40] None

# %%
a=np.array([10,20,30,40])
b=a.view()
print(a,a.base)
print(b,b.base)
# Out:
# [10 20 30 40] None
# [10 20 30 40] [10 20 30 40]
