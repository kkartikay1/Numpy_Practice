# %%
import numpy as np

# %%
a=np.array([3,5,7,9])
x=np.random.choice(a,p=[0.1,0.3,0.6,0.0],size=(100))
print(x)
# Out:
# [3 5 7 7 5 7 5 5 7 5 7 5 7 3 7 7 3 5 5 7 7 7 5 7 7 7 7 5 7 7 7 5 3 7 7 7 5
#  7 7 5 7 5 7 7 5 7 7 7 7 7 3 7 5 7 7 7 7 7 7 3 7 7 5 7 7 7 7 5 7 7 7 5 5 7
#  7 3 7 7 3 7 5 7 7 7 7 7 7 7 7 5 7 5 7 7 3 5 7 5 7 7]

# %%
print(x.size)
# Out:
# 100

# %%
a=np.array([3,5,7,9])
x=np.random.choice(a,p=[0.1,0.3,0.6,0.0],size=(10))
print(x)
# Out:
# [7 7 3 5 7 7 7 5 3 5]

# %%
a=np.array([3,5,7,9])
x=np.random.choice(a,p=[0.1,0.3,0.6,0.0],size=(3,5))
print(x)
# Out:
# [[5 7 5 7 7]
#  [3 7 5 7 7]
#  [5 7 5 5 5]]

# %%
a=np.array([3,5,7,9])
x=np.random.choice(a,p=[0.1,0.3,0.6,0.0],size=(2,2,2))
print(x)
# Out:
# [[[7 7]
#   [7 5]]
#
#  [[3 7]
#   [7 3]]]
