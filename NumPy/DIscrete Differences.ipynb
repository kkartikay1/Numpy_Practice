# %%
import numpy as np

# %%
arr1=np.array([10,30,50,60,80,60])
newarr=np.diff(arr1)
print(newarr)
# Out:
# [ 20  20  10  20 -20]

# %%
arr1=np.array([10,30,50,60,80,60])
newarr=np.diff(arr1,n=2)
print(newarr)
# Out:
# [  0 -10  10 -40]

# %%
arr1=np.array([1,2,3,4,5])
newarr=np.diff(arr1, n=2)
print(newarr)
# Out:
# [0 0 0]
