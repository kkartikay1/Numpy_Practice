# %%
import numpy as np

# %%
a=np.array([[10,20,30],[40,50,60],[70,80,90]])
print(a)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
a.shape=(9,)
print(a)
# Out:
# [10 20 30 40 50 60 70 80 90]

# %%
#Today Requirement is get multiple of 3 
#Create Boolean Array
b=a%3==0 #Here b is called Boolean Aarray of type ndarray
print(b,type(a))
# Out:
# [False False  True False False  True False False  True] <class 'numpy.ndarray'>

# %%
a[b]
# Out:
# array([30, 60, 90])

# %%
#get the multiple of 3
a[a%3==0]
# Out:
# array([30, 60, 90])

# %%
 #get the multiple of 5
a[a%5==0]
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
a=np.array([[20,-60,25],[-89,60,30],[50,90,-36]])
print(a,type(a))
# Out:
# [[ 20 -60  25]
#  [-89  60  30]
#  [ 50  90 -36]] <class 'numpy.ndarray'>

# %%
pa=a[a>0]
print(pa,type(pa))
# Out:
# [20 25 60 30 50 90] <class 'numpy.ndarray'>

# %%
a[a<0]
# Out:
# array([-60, -89, -36])

# %%
print(a)
# Out:
# [[ 20 -60  25]
#  [-89  60  30]
#  [ 50  90 -36]]

# %%
x=list(filter(lambda n: n>0,a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x=list(filter(lambda n: n>0,a))
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
